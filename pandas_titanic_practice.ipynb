# %%
import pandas as pd

# %%
pd.options.display.max_columns = 6

# %%
df = pd.read_csv('https://sololearn.com/uploads/files/titanic.csv')

# %%
df
# Out:
#      Survived  Pclass     Sex  ...  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  ...                 1                 0
# 1           1       1  female  ...                 1                 0
# 2           1       3  female  ...                 0                 0
# 3           1       1  female  ...                 1                 0
# 4           0       3    male  ...                 0                 0
# ..        ...     ...     ...  ...               ...               ...
# 882         0       2    male  ...                 0                 0
# 883         1       1  female  ...                 0                 0
# 884         0       3  female  ...                 1                 2
# 885         1       1    male  ...                 0                 0
# 886         0       3    male  ...                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
print(df.head())
# Out:
#    Survived  Pclass     Sex  ...  Siblings/Spouses  Parents/Children     Fare
# 0         0       3    male  ...                 1                 0   7.2500
# 1         1       1  female  ...                 1                 0  71.2833
# 2         1       3  female  ...                 0                 0   7.9250
# 3         1       1  female  ...                 1                 0  53.1000
# 4         0       3    male  ...                 0                 0   8.0500
#
# [5 rows x 7 columns]

# %%
print(df.describe())
# Out:
#          Survived      Pclass         Age  Siblings/Spouses  Parents/Children  \
# count  887.000000  887.000000  887.000000        887.000000        887.000000
# mean     0.385569    2.305524   29.471443          0.525366          0.383315
# std      0.487004    0.836662   14.121908          1.104669          0.807466
# min      0.000000    1.000000    0.420000          0.000000          0.000000
# 25%      0.000000    2.000000   20.250000          0.000000          0.000000
# 50%      0.000000    3.000000   28.000000          0.000000          0.000000
# 75%      1.000000    3.000000   38.000000          1.000000          0.000000
# max      1.000000    3.000000   80.000000          8.000000          6.000000
#
#             Fare
# count  887.00000
# mean    32.30542
# std     49.78204
# min      0.00000
# 25%      7.92500
# 50%     14.45420
# 75%     31.13750
# max    512.32920

# %%
col = df['Fare']

# %%
col
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 882    13.0000
# 883    30.0000
# 884    23.4500
# 885    30.0000
# 886     7.7500
# Name: Fare, Length: 887, dtype: float64

# %%
small_df = df[['Age', 'Survived', 'Sex']]

# %%
small_df.head()
# Out:
#     Age  Survived     Sex
# 0  22.0         0    male
# 1  38.0         1  female
# 2  26.0         1  female
# 3  35.0         1  female
# 4  35.0         0    male

# %%
df['male']  = df['Sex']=='male'#creating a new column that stores True if 'male' and False is 'female'

# %%
df.head()
# Out:
#    Survived  Pclass     Sex  ...  Parents/Children     Fare   male
# 0         0       3    male  ...                 0   7.2500   True
# 1         1       1  female  ...                 0  71.2833  False
# 2         1       3  female  ...                 0   7.9250  False
# 3         1       1  female  ...                 0  53.1000  False
# 4         0       3    male  ...                 0   8.0500   True
#
# [5 rows x 8 columns]

# %%
df['Fare'].values
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#         41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,  21.6792,
#         17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,  61.9792,
#         35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,   7.2292,
#         80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,  10.5   ,
#          8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,  73.5   ,
#         14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,  29.    ,
#         12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,  10.5   ,
# ...

# %%
df[['Pclass','Fare','Age']].values
# Out:
# array([[ 3.    ,  7.25  , 22.    ],
#        [ 1.    , 71.2833, 38.    ],
#        [ 3.    ,  7.925 , 26.    ],
#        ...,
#        [ 3.    , 23.45  ,  7.    ],
#        [ 1.    , 30.    , 26.    ],
#        [ 3.    ,  7.75  , 32.    ]])

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 882    27.0
# 883    19.0
# 884     7.0
# 885    26.0
# 886    32.0
# Name: Age, Length: 887, dtype: float64

# %%
arr = df[['Pclass','Fare','Age']].values

# %%
arr.shape
# Out:
# (887, 3)

# %%
df.shape
# Out:
# (887, 8)

# %%
arr[0,1]
# Out:
# 7.25

# %%
arr[0]
# Out:
# array([ 3.  ,  7.25, 22.  ])

# %%
arr[:,2]
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 27.  , 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 23.  ,
#        31.  , 22.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 26.  ,
#        19.  , 24.  , 23.  , 40.  , 48.  , 18.  , 66.  , 28.  , 42.  ,
#        18.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 30.  ,
#        20.  , 27.  , 16.  , 18.  ,  7.  , 21.  , 49.  , 29.  , 65.  ,
#        46.  , 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,  4.  ,
#        64.  ,  7.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  , 21.  ,
#        26.  , 32.  , 25.  , 23.  , 28.  ,  0.83, 30.  , 22.  , 29.  ,
#        31.  , 28.  , 17.  , 33.  , 16.  , 20.  , 23.  , 24.  , 29.  ,
#        20.  , 46.  , 26.  , 59.  , 22.  , 71.  , 23.  , 34.  , 34.  ,
#        28.  , 29.  , 21.  , 33.  , 37.  , 28.  , 21.  , 29.  , 38.  ,
#        28.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 , 29.  ,
# ...

# %%
arr[:,0]
# Out:
# array([3., 1., 3., 1., 3., 3., 1., 3., 3., 2., 3., 1., 3., 3., 3., 2., 3.,
#        2., 3., 3., 2., 2., 3., 1., 3., 3., 3., 1., 3., 3., 1., 1., 3., 2.,
#        1., 1., 3., 3., 3., 3., 3., 2., 2., 3., 3., 3., 3., 3., 3., 3., 3.,
#        1., 2., 1., 1., 2., 3., 2., 3., 3., 1., 1., 3., 1., 3., 2., 3., 3.,
#        3., 2., 3., 2., 3., 3., 3., 3., 3., 2., 3., 3., 3., 3., 1., 2., 3.,
#        3., 3., 1., 3., 3., 3., 1., 3., 3., 3., 1., 1., 2., 2., 3., 3., 1.,
#        3., 3., 3., 3., 3., 3., 3., 1., 3., 3., 3., 3., 3., 3., 2., 1., 3.,
#        2., 3., 2., 2., 1., 3., 3., 3., 3., 3., 3., 3., 3., 2., 2., 2., 1.,
#        1., 3., 1., 3., 3., 3., 3., 2., 2., 3., 3., 2., 2., 2., 1., 3., 3.,
#        3., 1., 3., 3., 3., 3., 3., 2., 3., 3., 3., 3., 1., 3., 1., 3., 1.,
#        3., 3., 3., 1., 3., 3., 1., 2., 3., 3., 2., 3., 2., 3., 1., 3., 1.,
#        3., 3., 2., 2., 3., 2., 1., 1., 3., 3., 3., 2., 3., 3., 3., 3., 3.,
# ...

# %% [markdown]
# ## Masking

# %%
mask = arr[:,2] < 18

# %%
mask
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#         True,  True, False, False, False,  True, False,  True, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False,  True, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False, False, False,  True,
#        False,  True, False, False,  True, False, False,  True, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False,  True, False, False, False,
# ...

# %%
arr[mask] # displaying the rows of children (Age<18)
# Out:
# array([[  3.    ,  21.075 ,   2.    ],
#        [  2.    ,  30.0708,  14.    ],
#        [  3.    ,  16.7   ,   4.    ],
#        [  3.    ,   7.8542,  14.    ],
#        [  3.    ,  29.125 ,   2.    ],
#        [  3.    ,   8.0292,  15.    ],
#        [  3.    ,  21.075 ,   8.    ],
#        [  3.    ,  11.2417,  14.    ],
#        [  2.    ,  41.5792,   3.    ],
#        [  3.    ,  21.6792,  16.    ],
#        [  3.    ,  39.6875,   7.    ],
#        [  2.    ,  27.75  ,   5.    ],
#        [  3.    ,  46.9   ,  11.    ],
#        [  3.    ,  27.9   ,   4.    ],
#        [  3.    ,  15.2458,   7.    ],
#        [  3.    ,   7.925 ,  17.    ],
#        [  3.    ,  46.9   ,  16.    ],
#        [  2.    ,  29.    ,   0.83  ],
#        [  2.    ,  10.5   ,  17.    ],
#        [  3.    ,  34.375 ,  16.    ],
#        [  3.    ,  14.4542,  14.5   ],
#        [  3.    ,  14.4583,  17.    ],
#        [  3.    ,  31.275 ,   2.    ],
#        [  3.    ,  11.2417,  12.    ],
# ...

# %%
arr[arr[:,0]==1] # to get the rows of the passengers belonging to the Pclass 1
# Out:
# array([[  1.    ,  71.2833,  38.    ],
#        [  1.    ,  53.1   ,  35.    ],
#        [  1.    ,  51.8625,  54.    ],
#        [  1.    ,  26.55  ,  58.    ],
#        [  1.    ,  35.5   ,  28.    ],
#        [  1.    , 263.    ,  19.    ],
#        [  1.    ,  27.7208,  40.    ],
#        [  1.    , 146.5208,  48.    ],
#        [  1.    ,  82.1708,  28.    ],
#        [  1.    ,  52.    ,  42.    ],
#        [  1.    ,  76.7292,  49.    ],
#        [  1.    ,  61.9792,  65.    ],
#        [  1.    ,  35.5   ,  46.    ],
#        [  1.    ,  80.    ,  38.    ],
#        [  1.    ,  83.475 ,  45.    ],
#        [  1.    ,  27.7208,  64.    ],
#        [  1.    ,  47.1   ,  28.    ],
#        [  1.    , 263.    ,  23.    ],
#        [  1.    ,  61.175 ,  46.    ],
#        [  1.    ,  34.6542,  71.    ],
#        [  1.    ,  63.3583,  23.    ],
#        [  1.    ,  77.2875,  21.    ],
#        [  1.    ,  52.    ,  47.    ],
#        [  1.    , 247.5208,  24.    ],
# ...

# %%
mask.sum() # counting the number of true values
# Out:
# 130

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(df['Age'], df['Fare'])

# %%
#color distrubution based on Pclass: as there are three classes, three color codes are visible in the graph

# %%
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(df['Age'], df['Fare'], c=df['Pclass'])

# %%
# Scatter plot of Fare and Pclass and color code according to the Survival

# %%
plt.xlabel('Fare')
plt.ylabel('Pclass')
plt.scatter(df['Fare'], df['Pclass'], c=df['Survived'])

# %% [markdown]
# ## Drawing Lines

# %%
plt.plot([0,80], [85,5]) #x1,x2 y1,y2

# %%
plt.xlabel('Fare')
plt.ylabel('Age')
plt.scatter(df['Fare'], df['Age'], c=df['Survived'])

# %%
# Logistic Regression gives not just a prediction (survived or not), but a probability (80% chance this person survived).
